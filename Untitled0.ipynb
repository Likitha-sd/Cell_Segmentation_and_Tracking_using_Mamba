# %% [markdown]
# <a href="https://colab.research.google.com/github/Likitha-sd/Cell_Segmentation_and_Tracking_using_Mamba/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cd /content/CTC_Vscode

# !git branch -m main

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/CTC_Vscode"
# Out:
# convert_labels.py  nnUNet		prepare_hela_dataset.py
# copy_labels.py	   organize_dataset.py	push_dataset.py

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/.shortcut-targets-by-id/1rbz3meZ0wEiw-RpoHx-BX5gdd2m1VpU9/CTC_Vscode/.git/

# %%
# !git branch -m main

# %%
# !git config --global user.email "likithasrimaddipatla@gmail.com"
# !git config --global user.name "Likitha-sd"

# %%
# !git add .
# !git commit -m "Initial commit of CTC_Vscode project"
# Out:
# [main (root-commit) e7fd843] Initial commit of CTC_Vscode project
#  6 files changed, 121 insertions(+)
#  create mode 100644 convert_labels.py
#  create mode 100644 copy_labels.py
#  create mode 160000 nnUNet
#  create mode 100644 organize_dataset.py
#  create mode 100644 prepare_hela_dataset.py
#  create mode 100644 push_dataset.py

# %%
# !git remote set-url origin https://github.com/Likitha-sd/Cell_Segmentation_and_Tracking_using_Mamba.git

# %%
# !git remote add origin https://github.com/Likitha-sd/Cell_Segmentation_and_Tracking_using_Mamba
# !git branch -M main
# Out:
# error: remote origin already exists.

# %%
# !git push -u origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install nnunetv2
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# ...
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# ...

# %%
import os
os.environ['nnUNet_raw'] = "/content/drive/MyDrive/CTC_Vscode/nnUNet/nnUNet_raw"
os.environ['nnUNet_preprocessed'] = "/content/drive/MyDrive/CTC_Vscode/nnUNet/nnUNet_preprocessed"
os.environ['nnUNet_results'] = "/content/drive/MyDrive/CTC_Vscode/nnUNet/nnUNet_results"

# %%
# !nnUNetv2_plan_and_preprocess -d 1 -c 2d -np 1 -pl resenc_presets
# Out:
# Fingerprint extraction...
# Dataset001_DIC-C2DH-HeLa
# Experiment planning...
# Traceback (most recent call last):
#   File "/usr/local/bin/nnUNetv2_plan_and_preprocess", line 8, in <module>
#     sys.exit(plan_and_preprocess_entry())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/nnunetv2/experiment_planning/plan_and_preprocess_entrypoints.py", line 188, in plan_and_preprocess_entry
#     plans_identifier = plan_experiments(args.d, args.pl, args.gpu_memory_target, args.preprocessor_name,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/nnunetv2/experiment_planning/plan_and_preprocess_api.py", line 97, in plan_experiments
#     _, plans_identifier = plan_experiment_dataset(d, experiment_planner, gpu_memory_target_in_gb,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
import torch
print("GPU available:", torch.cuda.is_available())
# Out:
# GPU available: True

# %%
import os
os.environ['nnUNet_raw'] = "/content/drive/MyDrive/Colab Notebooks/CTC_Vscode/nnUNet/nnUNet_raw"
os.environ['nnUNet_preprocessed'] = "/content/drive/MyDrive/Colab Notebooks/CTC_Vscode/nnUNet/nnUNet_preprocessed"
os.environ['nnUNet_results'] = "/content/drive/MyDrive/Colab Notebooks/CTC_Vscode/nnUNet/nnUNet_results"

# %%
# !pip install --upgrade blosc2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 74.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: blosc2
#     Found existing installation: blosc2 4.4.5
#     Uninstalling blosc2-4.4.5:
#       Successfully uninstalled blosc2-4.4.5
# ...

# %%
# !nnUNetv2_plan_and_preprocess -d 1 -c 2d -np 1 --disable_multiprocessing
# Out:
# usage: nnUNetv2_plan_and_preprocess [-h] [-d D [D ...]] [-fpe FPE]
#                                     [-npfp NPFP] [--verify_dataset_integrity]
#                                     [--no_pp] [--clean] [-pl PL]
#                                     [-gpu_memory_target GPU_MEMORY_TARGET]
#                                     [-preprocessor_name PREPROCESSOR_NAME]
#                                     [-overwrite_target_spacing OVERWRITE_TARGET_SPACING [OVERWRITE_TARGET_SPACING ...]]
#                                     [-overwrite_plans_name OVERWRITE_PLANS_NAME]
#                                     [-c C [C ...]] [-np NP [NP ...]]
#                                     [--verbose] [--no_pbar]
# nnUNetv2_plan_and_preprocess: error: unrecognized arguments: --disable_multiprocessing

# %%
# !pip install --upgrade blosc2

# %%
# !pip install nnunetv2
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# ...
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# ...
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# ...
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 447, in run
# ^C

# %%
# !nnUNetv2_plan_and_preprocess -d 1 -c 2d -np 1 -pl resenc_presets
# Out:
# Fingerprint extraction...
# Traceback (most recent call last):
#   File "/usr/local/bin/nnUNetv2_plan_and_preprocess", line 8, in <module>
#     sys.exit(plan_and_preprocess_entry())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/nnunetv2/experiment_planning/plan_and_preprocess_entrypoints.py", line 183, in plan_and_preprocess_entry
#     extract_fingerprints(args.d, args.fpe, args.npfp, args.verify_dataset_integrity, args.clean, args.verbose,
#   File "/usr/local/lib/python3.12/dist-packages/nnunetv2/experiment_planning/plan_and_preprocess_api.py", line 50, in extract_fingerprints
#     extract_fingerprint_dataset(d, fingerprint_extractor_class, num_processes, check_dataset_integrity, clean,
#   File "/usr/local/lib/python3.12/dist-packages/nnunetv2/experiment_planning/plan_and_preprocess_api.py", line 26, in extract_fingerprint_dataset
#     dataset_name = convert_id_to_dataset_name(dataset_id)
# ...

# %%
import os
os.environ['nnUNet_raw'] = "/content/drive/MyDrive/Colab Notebooks/CTC_Vscode/nnUNet/nnUNet_raw"
os.environ['nnUNet_preprocessed'] = "/content/drive/MyDrive/Colab Notebooks/CTC_Vscode/nnUNet/nnUNet_preprocessed"
os.environ['nnUNet_results'] = "/content/drive/MyDrive/Colab Notebooks/CTC_Vscode/nnUNet/nnUNet_results"

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/CTC_Vscode/nnUNet/nnUNet_raw/Dataset001_DIC-C2DH-HeLa/imagesTr"
# !ls "/content/drive/MyDrive/Colab Notebooks/CTC_Vscode/nnUNet/nnUNet_raw/Dataset001_DIC-C2DH-HeLa/labelsTr"
# Out:
# case0000_0000.tif  case0042_0000.tif  case0084_0000.tif  case0126_0000.tif
# case0001_0000.tif  case0043_0000.tif  case0085_0000.tif  case0127_0000.tif
# case0002_0000.tif  case0044_0000.tif  case0086_0000.tif  case0128_0000.tif
# case0003_0000.tif  case0045_0000.tif  case0087_0000.tif  case0129_0000.tif
# case0004_0000.tif  case0046_0000.tif  case0088_0000.tif  case0130_0000.tif
# case0005_0000.tif  case0047_0000.tif  case0089_0000.tif  case0131_0000.tif
# case0006_0000.tif  case0048_0000.tif  case0090_0000.tif  case0132_0000.tif
# case0007_0000.tif  case0049_0000.tif  case0091_0000.tif  case0133_0000.tif
# case0008_0000.tif  case0050_0000.tif  case0092_0000.tif  case0134_0000.tif
# case0009_0000.tif  case0051_0000.tif  case0093_0000.tif  case0135_0000.tif
# case0010_0000.tif  case0052_0000.tif  case0094_0000.tif  case0136_0000.tif
# case0011_0000.tif  case0053_0000.tif  case0095_0000.tif  case0137_0000.tif
# ...

# %%
# 2. Set nnU-Net environment variables
import os
os.environ['nnUNet_raw'] = "/content/drive/MyDrive/Colab Notebooks/CTC_Vscode/nnUNet/nnUNet_raw"
os.environ['nnUNet_preprocessed'] = "/content/drive/MyDrive/Colab Notebooks/CTC_Vscode/nnUNet/nnUNet_preprocessed"
os.environ['nnUNet_results'] = "/content/drive/MyDrive/Colab Notebooks/CTC_Vscode/nnUNet/nnUNet_results"

# 3. Verify dataset folder exists

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/CTC_Vscode/nnUNet/nnUNet_raw/Dataset001_DIC-C2DH-HeLa"
# Out:
# dataset.json  imagesTr	labelsTr

# %%
# !nnUNetv2_plan_and_preprocess -d 1 -c 2d -np 1 -pl resenc_presets
# Out:
# Fingerprint extraction...
# Dataset001_DIC-C2DH-HeLa
# Experiment planning...
# Traceback (most recent call last):
#   File "/usr/local/bin/nnUNetv2_plan_and_preprocess", line 8, in <module>
#     sys.exit(plan_and_preprocess_entry())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/nnunetv2/experiment_planning/plan_and_preprocess_entrypoints.py", line 188, in plan_and_preprocess_entry
#     plans_identifier = plan_experiments(args.d, args.pl, args.gpu_memory_target, args.preprocessor_name,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/nnunetv2/experiment_planning/plan_and_preprocess_api.py", line 97, in plan_experiments
#     _, plans_identifier = plan_experiment_dataset(d, experiment_planner, gpu_memory_target_in_gb,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# Set nnU-Net environment variables
import os
os.environ['nnUNet_raw'] = "/content/drive/MyDrive/Colab Notebooks/CTC_Vscode/nnUNet/nnUNet_raw"
os.environ['nnUNet_preprocessed'] = "/content/drive/MyDrive/Colab Notebooks/CTC_Vscode/nnUNet/nnUNet_preprocessed"
os.environ['nnUNet_results'] = "/content/drive/MyDrive/Colab Notebooks/CTC_Vscode/nnUNet/nnUNet_results"

# %%
# !nnUNetv2_plan_and_preprocess -d 1 -c 2d -np 1 -pl resenc_presets
# Out:
# Fingerprint extraction...
# Dataset001_DIC-C2DH-HeLa
# Experiment planning...
# Traceback (most recent call last):
#   File "/usr/local/bin/nnUNetv2_plan_and_preprocess", line 8, in <module>
#     sys.exit(plan_and_preprocess_entry())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/nnunetv2/experiment_planning/plan_and_preprocess_entrypoints.py", line 188, in plan_and_preprocess_entry
#     plans_identifier = plan_experiments(args.d, args.pl, args.gpu_memory_target, args.preprocessor_name,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/nnunetv2/experiment_planning/plan_and_preprocess_api.py", line 97, in plan_experiments
#     _, plans_identifier = plan_experiment_dataset(d, experiment_planner, gpu_memory_target_in_gb,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
